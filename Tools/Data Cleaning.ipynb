# %%
import numpy as np
import pandas as pd
import math

# %%
df = pd.read_csv('C:/Users/Gordon Huy/Documents/Data Visualization Project/Datasets/co2-emissions-and-gdp.csv',encoding = 'unicode_escape')
df = pd.DataFrame(df, dtype=object)
df.dropna()
# Out:
#         Entity Code  Year Annual CO2 emissions  \
# 124    Albania  ALB  1990            5444704.0
# 125    Albania  ALB  1991            4228256.0
# 126    Albania  ALB  1992            2495184.0
# 127    Albania  ALB  1993            2315648.0
# 128    Albania  ALB  1994            1912608.0
# ...        ...  ...   ...                  ...
# 8742  Zimbabwe  ZWE  2015           12225821.0
# 8743  Zimbabwe  ZWE  2016           10737567.0
# 8744  Zimbabwe  ZWE  2017            9581633.0
# 8745  Zimbabwe  ZWE  2018           11854367.0
# 8746  Zimbabwe  ZWE  2019           10949084.0
#
#      Annual consumption-based CO2 emissions  \
# 124                            5435844.3598
# 125                            4507016.8058
# 126                            2842828.1278
# 127                            2603634.2876
# 128                            2311874.1767
# ...                                     ...
# 8742                          13350047.4505
# ...

# %%
df1 = df.drop(df.index[(df['Year']<= 1999) & (df['Year'] >= 1600)])
df2 = df1.drop(df1.index[(df1["Annual CO2 emissions"] >= 600000000)])
df2
# Out:
#             Entity Code  Year Annual CO2 emissions
# 51     Afghanistan  AFG  2000               757672
# 52     Afghanistan  AFG  2001               797962
# 53     Afghanistan  AFG  2002              1051609
# 54     Afghanistan  AFG  2003              1185951
# 55     Afghanistan  AFG  2004               889167
# ...            ...  ...   ...                  ...
# 24665     Zimbabwe  ZWE  2016             10737567
# 24666     Zimbabwe  ZWE  2017              9581633
# 24667     Zimbabwe  ZWE  2018             11854367
# 24668     Zimbabwe  ZWE  2019             10949084
# 24669     Zimbabwe  ZWE  2020             10531342
#
# [4485 rows x 4 columns]

# %%
df2 = df.iloc[:, np.r_[1, 74:105]]
df2

# %%
options = ["World"]
df3 = df[df["Entity"].isin(options)]
df3
# Out:
#      Entity      Code  Year Annual CO2 emissions  \
# 8624  World  OWID_WRL  1990        22749574360.0
# 8625  World  OWID_WRL  1991        23238102148.0
# 8626  World  OWID_WRL  1992        22569624280.0
# 8627  World  OWID_WRL  1993        22803495349.0
# 8628  World  OWID_WRL  1994        22964583359.0
# 8629  World  OWID_WRL  1995        23453944453.0
# 8630  World  OWID_WRL  1996        24154961206.0
# 8631  World  OWID_WRL  1997        24300550431.0
# 8632  World  OWID_WRL  1998        24206271270.0
# 8633  World  OWID_WRL  1999        24518962288.0
# 8634  World  OWID_WRL  2000        25234207250.0
# 8635  World  OWID_WRL  2001        25451054498.0
# 8636  World  OWID_WRL  2002        26039191477.0
# 8637  World  OWID_WRL  2003        27366723291.0
# 8638  World  OWID_WRL  2004        28627533033.0
# 8639  World  OWID_WRL  2005        29602777196.0
# 8640  World  OWID_WRL  2006        30583530081.0
# 8641  World  OWID_WRL  2007        31493741589.0
# ...

# %%
df4 = df.groupby(by=[], as_index=False).sum()
df4
# Out:
#   Country/Region  4/1/20  4/2/20  4/3/20  4/4/20  4/5/20  4/6/20  4/7/20  \
# 0         France   57125   59227   64452   47376   48225   50884   47395
# 1          Italy  110574  115242  119827  124632  128948  132547  135586
# 2             US  223255  255531  287932  319777  349017  380799  410835
# 3        Vietnam     218     233     237     240     241     245     249
#
#    4/8/20  4/9/20  ...  4/22/20  4/23/20  4/24/20  4/25/20  4/26/20  4/27/20  \
# 0   51250   55034  ...   158867   157158   159969   161647   162280   165966
# 1  139422  143626  ...   187327   189973   192994   195351   197675   199414
# 2  441898  477508  ...   849927   881892   913857   944771   970742   995392
# 3     251     255  ...      268      268      270      270      270      270
#
#    4/28/20  4/29/20  4/30/20   5/1/20
# 0   169098   167643   168861   169387
# 1   201505   203591   205463   207428
# 2  1019965  1046817  1076519  1111411
# 3      270      270      270      270
#
# ...

# %%
df3.to_csv('C:/Users/Gordon Huy/Documents/file_name.csv')
